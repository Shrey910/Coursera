# %% [markdown]
# <a href="https://colab.research.google.com/github/Shrey910/Coursera/blob/master/Udemy_Courses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fd9a0d7b-d8c9-4575-b529-293f29c8ec03" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd9a0d7b-d8c9-4575-b529-293f29c8ec03">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("UdemyCourses.csv")

# %%
#Data Loading and Overview:

#The project initiates with loading the dataset, "Udemy Courses.csv," into a Pandas DataFrame. The dataset provides a comprehensive view of courses spanning subjects like Musical Instruments, Business Finance, Graphic Design, and Web Development.
df.head(5)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
#Subjects and Course Count:

#An exploration of unique subjects reveals that Udemy offers courses in Musical Instruments, Business Finance, Graphic Design, and Web Development. Subsequently, the project identifies Web Development as the subject with the maximum course count, totaling 1200.


df[df['subject'] == 'Web Development'].value_counts().sum()
# Out:
# 1200

# %%
#Pricing Analysis:

#The analysis segregates courses based on their pricing, distinguishing
#between free and paid offerings. Further search reveals 3372 paid courses
#and a list of free courses provided by Udemy.

df[df['price'] != 'Free'].value_counts().sum()

df[df['price'] == 'Free']
# Out:
#       course_id                                       course_title  is_paid  \
# 41       286070        5 lecciones que todo guitarrista debe tomar    False
# 49       696630  7 Ways A Beginner Guitarist Can Sound Better, ...    False
# 57       955914  A beginner`s guide to fingerpicking and strumm...    False
# 67       270976                             A how to guide in HTML    False
# 74      1214144  ¡Triunfar en La Bolsa de Valores No Requiere d...    False
# ...         ...                                                ...      ...
# 3620     552598  WordPress in under an hour - Create/manage you...    False
# 3638    1068590                     Wordpress Website Mastery 2017    False
# 3652     752706  Write quicker HTML5 and CSS 3; productivity ha...    False
# 3674    1257976  Your First 10 Guitar Lessons - Learn how to pl...    False
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
#
# ...

# %%
"""Best and Least Selling Courses:

Courses with the highest and lowest subscriber counts are unveiled, showcasing the top-selling and least-selling courses on the platform.
"""
df_sorted = df.sort_values(by = "num_subscribers", ascending= False)

top_selling_courses = df.head(5)
least_selling_courses = df.tail(5)

print("Top selling courses:")
print(top_selling_courses[['course_title','num_subscribers']])

print("Least selling courses: ")
print(least_selling_courses[['course_title','num_subscribers']])
# Out:
# Top selling courses:
#                                         course_title  num_subscribers
# 0  #1 Piano Hand Coordination: Play 10th Ballad i...             3137
# 1  #10 Hand Coordination - Transfer Chord Ballad ...             1593
# 2  #12 Hand Coordination: Let your Hands dance wi...              482
# 3  #4 Piano Hand Coordination: Fun Piano Runs in ...              850
# 4  #5  Piano Hand Coordination:  Piano Runs in 2 ...              940
# Least selling courses:
#                                            course_title  num_subscribers
# 3677  Your Own Site in 45 Min: The Complete Wordpres...             1566
# 3678    Your Second Course on Piano: Two Handed Playing             1018
# 3679  Zend Framework 2: Learn the PHP framework ZF2 ...              723
# 3680  Zoho Books Gestion Financière d'Entreprise pas...              229
# 3681                Zombie Apocalypse Photoshop Actions               12

# %%
"""Subject-Specific Price Filters:

The project drills down into specific subjects, applying price filters.
It displays all Graphic Design courses priced below 100 Dollars and Web Development courses priced above 50 Dollars.
"""

df['price'] = pd.to_numeric(df['price'], errors= 'coerce')

#graphic_design = df[(df['subject'] == 'Graphic Design') & (df['price'] < 100)]
#print(graphic_design)

web_development = df[(df['subject'] == 'Web Development') & (df['price'] > 50)].sort_values(by = ['subject'], ascending= False)
print(web_development)
# Out:
#       course_id                                       course_title  is_paid  \
# 11        64605                                         1 Hour CSS     True
# 2612     715516  Modern Web Development with Laravel 5.2 (PHP F...     True
# 2570    1223012  Mastering 'Native CSS Shapes To Build Modern W...     True
# 2582     736250                    Mastering Thymeleaf with Spring     True
# 2583     708514                               Mastering TypeScript     True
# ...         ...                                                ...      ...
# 1458     818990  Git a Web Developer Job: Mastering the Modern ...     True
# 1448     842728          Getting Started with NodeJS for Beginners     True
# 1447     352748                       Getting Started with Magento     True
# 1445    1267892                    Getting started with JavaScript     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
#
# ...

# %%
"""Python-Related Courses:

A query is executed to extract courses related to Python, providing insights into the programming language's prominence on the Udemy platform.
"""

python_courses = df[df['course_title'].str.contains('Python')]
print(python_courses)
# Out:
#       course_id                                       course_title  is_paid  \
# 216      599504  Advanced Scalable Python Web Development Using...     True
# 777       47963  Coding for Entrepreneurs: Learn Python, Django...     True
# 814      631128  Complete Python Web Course: Build 8 Python Web...     True
# 842      186096  Core: A Web App Reference Guide for Django, Py...     True
# 1400     394832  Fun and creative web engineering with Python a...    False
# 1932    1038538            Introduction to QGIS Python Programming     True
# 1969     902888          Investment Portfolio Analysis with Python     True
# 2294     391546        Learn Python and Django: Payment Processing     True
# 2295    1063722            Learn Python Django - A Hands-On Course     True
# 2341     546848  Learn to code in Python and learn Adobe Photos...     True
# 2906     368340    Professional Python Web Development Using Flask     True
# ...

# %%
"""Courses Published in 2015:

Courses published in 2015 are identified, with 1014 courses falling within this temporal scope.
"""

df['published_timestamp'].str.contains('2015').value_counts()
# Out:
# published_timestamp
# False    2668
# True     1014
# Name: count, dtype: int64

# %%
"""Maximum Subscribers by Course Level:

The analysis categorizes courses based on difficulty levels - All Levels, Intermediate Level, Beginner Level, and Expert Level, revealing the maximum number of subscribers for each category.
"""

df['level'].value_counts()
# Out:
# level
# All Levels            1932
# Beginner Level        1271
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64
